# %%
val = """(59,0; 2,10), (118,0; 2,79), (66,0; 4,23), 
(43,0; 2,65), (142,0; 3,76), (142,0; 2,63), 
(61,0; 4,53), (34,0; 2,59), (21,0; 5,50), 
(20,0; 2,39), (42,0; 2,86), (29,0; 4,31), 
(17,0; 3,09), (80,0; 6,73), (32,0; 3,63), 
(41,0; 2,61), (43,0; 3,30), (15,0; 1,89), 
(48,0; 2,63), (78,0; 2,13), (29,0; 3,20), 
(28,0; 3,95), (50,0; 3,66), (35,0; 3,49), 
(48,0; 2,91), (42,0; 1,71), (142,0; 2,96), 
(23,0; 1,75), (36,0; 3,66), (14,0; 3,32), 
(36,0; 4,81), (32,0; 3,91), (79,0; 3,91), 
(30,0; 3,63), (43,5; 3,66), (69,0; 7,14), 
(26,0; 5,22), (32,0; 4,06), (69,0; 3,51), 
(61,0; 3,56), (39,0; 6,26), (41,0; 7,36), 
81,0; 8,28), (89,0; 2,59), (68,5; 3,25), 
(32,0; 3,33), (50,0; 2,22), (54,0; 2,61), 
(50,0; 4,10), (15,0; 2,63) """

# %%
val_split = val.split(', ')
X = ""
Y = ""

for i in val_split:
    print(i)
    x, y = tuple(list(i.split("; ")))
    X += str(x)[1:] + '\n'
    Y += str(y)[:-1] + '\n'


print(X)
print("__" * 100)
print(Y)
# Out:
# (59,0; 2,10)
# (118,0; 2,79)
# (66,0; 4,23)
#
# (43,0; 2,65)
# (142,0; 3,76)
# (142,0; 2,63)
#
# (61,0; 4,53)
# (34,0; 2,59)
# (21,0; 5,50)
#
# (20,0; 2,39)
# (42,0; 2,86)
# (29,0; 4,31)
#
# (17,0; 3,09)
# (80,0; 6,73)
# (32,0; 3,63)
#
# (41,0; 2,61)
# (43,0; 3,30)
# (15,0; 1,89)
#
# (48,0; 2,63)
# (78,0; 2,13)
# (29,0; 3,20)
#
# (28,0; 3,95)
# (50,0; 3,66)
# (35,0; 3,49)
#
# (48,0; 2,91)
# (42,0; 1,71)
# (142,0; 2,96)
#
# (23,0; 1,75)
# (36,0; 3,66)
# (14,0; 3,32)
#
# (36,0; 4,81)
# (32,0; 3,91)
# (79,0; 3,91)
#
# (30,0; 3,63)
# (43,5; 3,66)
# (69,0; 7,14)
#
# (26,0; 5,22)
# (32,0; 4,06)
# (69,0; 3,51)
#
# (61,0; 3,56)
# (39,0; 6,26)
# (41,0; 7,36)
#
# 81,0; 8,28)
# (89,0; 2,59)
# (68,5; 3,25)
#
# (32,0; 3,33)
# (50,0; 2,22)
# (54,0; 2,61)
#
# (50,0; 4,10)
# (15,0; 2,63)
# 59,0
# 118,0
# 66,0
# (43,0
# 142,0
# 142,0
# (61,0
# 34,0
# 21,0
# (20,0
# 42,0
# 29,0
# (17,0
# 80,0
# 32,0
# (41,0
# 43,0
# 15,0
# (48,0
# 78,0
# 29,0
# (28,0
# 50,0
# 35,0
# (48,0
# 42,0
# 142,0
# (23,0
# ...
